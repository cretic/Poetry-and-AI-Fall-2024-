# %% [markdown]
# <a href="https://colab.research.google.com/github/cretic/Poetry-and-AI-Fall-2024-/blob/main/DH_Lab_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# One of the challenges in the final project is finding a way to output, store, and ultimately display your data in a clean, easy to read format. DH Lab 5 will give you an opportunity to think about how you want to tackle that with your project.

# %% [markdown]
# First, here's a demo on a few different formatting options using sonnet 129. In each, let's say we want to display the line, track its enjambments, and record a few other metrics about the line.

# %%
sonnet_129 = """The expense of spirit in a waste of shame
Is lust in action; and till action, lust
Is perjured, murderous, bloody, full of blame,
Savage, extreme, rude, cruel, not to trust,
Enjoyed no sooner but despisèd straight,
Past reason hunted; and, no sooner had
Past reason hated as a swallowed bait
On purpose laid to make the taker mad;
Mad in pursuit and in possession so,
Had, having, and in quest to have, extreme;
A bliss in proof and proved, a very woe;
Before, a joy proposed; behind, a dream.
    All this the world well knows; yet none knows well
    To shun the heaven that leads men to this hell."""

# note the tripe quotes, these allow line breaks to be preserved in the sonnet

# %%
print(sonnet_129)
# Out:
# The expense of spirit in a waste of shame
# Is lust in action; and till action, lust
# Is perjured, murderous, bloody, full of blame,
# Savage, extreme, rude, cruel, not to trust,
# Enjoyed no sooner but despisèd straight,
# Past reason hunted; and, no sooner had
# Past reason hated as a swallowed bait
# On purpose laid to make the taker mad;
# Mad in pursuit and in possession so,
# Had, having, and in quest to have, extreme;
# A bliss in proof and proved, a very woe;
# Before, a joy proposed; behind, a dream.
#     All this the world well knows; yet none knows well
#     To shun the heaven that leads men to this hell.

# %%
import spacy

# Load SpaCy English model
nlp = spacy.load("en_core_web_sm")

# Split text into lines
lines = sonnet_129.split("\n")

# Initialize results
results = []

# Process each line
for i in range(len(lines) - 1):
    line = lines[i].strip()
    next_line = lines[i + 1].strip()

    # Parse lines with SpaCy
    doc = nlp(line)
    next_doc = nlp(next_line)

    # Check for punctuation at the end of the line
    enjambed = "no" if line[-1] in ".;!?," else "yes"

    # Check for substantial enjambment (based on syntactic dependencies)
    last_token = doc[-1]
    substantial = "yes" if last_token.dep_ in ["cc", "prep", "conj", "det"] else "no"

    # Append results
    results.append({"Line": line, "Enjambed": enjambed, "Substantial Enjambment": substantial})

# Print results
for result in results:
    print(result)
# Out:
# {'Line': 'The expense of spirit in a waste of shame', 'Enjambed': 'yes', 'Substantial Enjambment': 'no'}
# {'Line': 'Is lust in action; and till action, lust', 'Enjambed': 'yes', 'Substantial Enjambment': 'yes'}
# {'Line': 'Is perjured, murderous, bloody, full of blame,', 'Enjambed': 'no', 'Substantial Enjambment': 'no'}
# {'Line': 'Savage, extreme, rude, cruel, not to trust,', 'Enjambed': 'no', 'Substantial Enjambment': 'no'}
# {'Line': 'Enjoyed no sooner but despisèd straight,', 'Enjambed': 'no', 'Substantial Enjambment': 'no'}
# {'Line': 'Past reason hunted; and, no sooner had', 'Enjambed': 'yes', 'Substantial Enjambment': 'yes'}
# {'Line': 'Past reason hated as a swallowed bait', 'Enjambed': 'yes', 'Substantial Enjambment': 'no'}
# {'Line': 'On purpose laid to make the taker mad;', 'Enjambed': 'no', 'Substantial Enjambment': 'no'}
# {'Line': 'Mad in pursuit and in possession so,', 'Enjambed': 'no', 'Substantial Enjambment': 'no'}
# {'Line': 'Had, having, and in quest to have, extreme;', 'Enjambed': 'no', 'Substantial Enjambment': 'no'}
# {'Line': 'A bliss in proof and proved, a very woe;', 'Enjambed': 'no', 'Substantial Enjambment': 'no'}
# {'Line': 'Before, a joy proposed; behind, a dream.', 'Enjambed': 'no', 'Substantial Enjambment': 'no'}
# {'Line': 'All this the world well knows; yet none knows well', 'Enjambed': 'yes', 'Substantial Enjambment': 'no'}

# %%
## run this cell to install prosodic, then restart runtime as requested

# !apt-get install espeak libespeak1 libespeak-dev
# !pip install -U prosodic

import prosodic
prosodic.logger.setLevel('ERROR')

# these are the meter parameters.
# if you want to play around with different rules and values, do that and make sure to change the inputs and rerun

constraints={
    'w_peak':3.0,
    'w_stress':1.0,
    's_unstress':1.0,
    'unres_across':1.0,
    'unres_within':1.0,
    'pentameter':20.0,
}
meter = prosodic.Meter(
    constraints=constraints,
    resolve_optionality=True,
    max_s=1,
    max_w=2,
)

meter.to_dict()
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   espeak-data libportaudio2 libsonic0
# The following NEW packages will be installed:
#   espeak espeak-data libespeak-dev libespeak1 libportaudio2 libsonic0
# 0 upgraded, 6 newly installed, 0 to remove and 49 not upgraded.
# Need to get 1,575 kB of archives.
# After this operation, 3,802 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libportaudio2 amd64 19.6.0-1.1 [65.3 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsonic0 amd64 0.2.0-11build1 [10.3 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 espeak-data amd64 1.48.15+dfsg-3 [1,085 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libespeak1 amd64 1.48.15+dfsg-3 [156 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/universe amd64 espeak amd64 1.48.15+dfsg-3 [64.2 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libespeak-dev amd64 1.48.15+dfsg-3 [193 kB]
# Fetched 1,575 kB in 2s (719 kB/s)
# Selecting previously unselected package libportaudio2:amd64.
# (Reading database ... 123629 files and directories currently installed.)
# Preparing to unpack .../0-libportaudio2_19.6.0-1.1_amd64.deb ...
# Unpacking libportaudio2:amd64 (19.6.0-1.1) ...
# Selecting previously unselected package libsonic0:amd64.
# Preparing to unpack .../1-libsonic0_0.2.0-11build1_amd64.deb ...
# Unpacking libsonic0:amd64 (0.2.0-11build1) ...
# Selecting previously unselected package espeak-data:amd64.
# Preparing to unpack .../2-espeak-data_1.48.15+dfsg-3_amd64.deb ...
# Unpacking espeak-data:amd64 (1.48.15+dfsg-3) ...
# Selecting previously unselected package libespeak1:amd64.
# Preparing to unpack .../3-libespeak1_1.48.15+dfsg-3_amd64.deb ...
# Unpacking libespeak1:amd64 (1.48.15+dfsg-3) ...
# Selecting previously unselected package espeak.
# Preparing to unpack .../4-espeak_1.48.15+dfsg-3_amd64.deb ...
# Unpacking espeak (1.48.15+dfsg-3) ...
# Selecting previously unselected package libespeak-dev:amd64.
# Preparing to unpack .../5-libespeak-dev_1.48.15+dfsg-3_amd64.deb ...
# Unpacking libespeak-dev:amd64 (1.48.15+dfsg-3) ...
# Setting up libportaudio2:amd64 (19.6.0-1.1) ...
# Setting up libsonic0:amd64 (0.2.0-11build1) ...
# Setting up espeak-data:amd64 (1.48.15+dfsg-3) ...
# Setting up libespeak1:amd64 (1.48.15+dfsg-3) ...
# Setting up espeak (1.48.15+dfsg-3) ...
# Setting up libespeak-dev:amd64 (1.48.15+dfsg-3) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# Collecting prosodic
#   Downloading prosodic-2.0.8-py3-none-any.whl.metadata (37 kB)
# Collecting ftfy (from prosodic)
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting langdetect (from prosodic)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 15.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from prosodic) (2.2.2)
# Collecting gruut-ipa (from prosodic)
#   Downloading gruut-ipa-0.13.0.tar.gz (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 7.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from prosodic) (1.26.4)
# Collecting multiset (from prosodic)
#   Downloading multiset-3.2.0-py2.py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from prosodic) (3.9.1)
# Collecting phonemizer (from prosodic)
#   Downloading phonemizer-3.3.0-py3-none-any.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: orjson in /usr/local/lib/python3.10/dist-packages (from prosodic) (3.10.11)
# Collecting ordered-set (from prosodic)
#   Downloading ordered_set-4.1.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from prosodic) (8.1.7)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.10/dist-packages (from prosodic) (0.8.1)
# Collecting logmap (from prosodic)
#   Downloading logmap-0.0.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting loguru (from prosodic)
#   Downloading loguru-0.7.2-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from prosodic) (7.34.0)
# Requirement already satisfied: flask in /usr/local/lib/python3.10/dist-packages (from prosodic) (3.0.3)
# Collecting flask-socketio (from prosodic)
#   Downloading Flask_SocketIO-5.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting gevent (from prosodic)
#   Downloading gevent-24.11.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting gevent-websocket (from prosodic)
#   Downloading gevent_websocket-0.10.1-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from prosodic) (1.13.1)
# Collecting unicodecsv (from prosodic)
#   Downloading unicodecsv-0.14.1.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from prosodic) (6.0.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from prosodic) (2024.9.11)
# Collecting munkres (from prosodic)
#   Downloading munkres-1.1.4-py2.py3-none-any.whl.metadata (980 bytes)
# Collecting hashstash[rec] (from prosodic)
#   Downloading hashstash-0.2.11-py3-none-any.whl.metadata (29 kB)
# Collecting stanza (from prosodic)
#   Downloading stanza-1.9.2-py3-none-any.whl.metadata (13 kB)
# Collecting svgling (from prosodic)
#   Downloading svgling-0.5.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: plotnine in /usr/local/lib/python3.10/dist-packages (from prosodic) (0.14.1)
# Requirement already satisfied: Werkzeug>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from flask->prosodic) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.10/dist-packages (from flask->prosodic) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.10/dist-packages (from flask->prosodic) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.10/dist-packages (from flask->prosodic) (1.9.0)
# Collecting python-socketio>=5.0.2 (from flask-socketio->prosodic)
#   Downloading python_socketio-5.11.4-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from ftfy->prosodic) (0.2.13)
# Collecting zope.event (from gevent->prosodic)
#   Downloading zope.event-5.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting zope.interface (from gevent->prosodic)
#   Downloading zope.interface-7.1.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: greenlet>=3.1.1 in /usr/local/lib/python3.10/dist-packages (from gevent->prosodic) (3.1.1)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from hashstash[rec]->prosodic) (17.0.0)
# Collecting lmdb (from hashstash[rec]->prosodic)
#   Downloading lmdb-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Collecting lz4 (from hashstash[rec]->prosodic)
#   Downloading lz4-4.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.7 kB)
# Collecting ultradict (from hashstash[rec]->prosodic)
#   Downloading UltraDict-0.0.6.tar.gz (197 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.6/197.6 kB 15.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->prosodic) (75.1.0)
# Collecting jedi>=0.16 (from ipython->prosodic)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->prosodic) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->prosodic) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->prosodic) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->prosodic) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->prosodic) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->prosodic) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->prosodic) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->prosodic) (4.9.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect->prosodic) (1.16.0)
# Collecting humanfriendly (from logmap->prosodic)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from logmap->prosodic) (4.66.6)
# Collecting multiprocess (from logmap->prosodic)
#   Downloading multiprocess-0.70.17-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->prosodic) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->prosodic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->prosodic) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->prosodic) (2024.2)
# Collecting segments (from phonemizer->prosodic)
#   Downloading segments-2.2.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: attrs>=18.1 in /usr/local/lib/python3.10/dist-packages (from phonemizer->prosodic) (24.2.0)
# Collecting dlinfo (from phonemizer->prosodic)
#   Downloading dlinfo-1.2.1-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from phonemizer->prosodic) (4.12.2)
# Requirement already satisfied: matplotlib>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from plotnine->prosodic) (3.8.0)
# Requirement already satisfied: mizani~=0.13.0 in /usr/local/lib/python3.10/dist-packages (from plotnine->prosodic) (0.13.0)
# Requirement already satisfied: statsmodels>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from plotnine->prosodic) (0.14.4)
# Collecting emoji (from stanza->prosodic)
#   Downloading emoji-2.14.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.10/dist-packages (from stanza->prosodic) (4.25.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from stanza->prosodic) (2.32.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from stanza->prosodic) (3.4.2)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from stanza->prosodic) (2.5.1+cu121)
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/dist-packages (from stanza->prosodic) (2.1.0)
# Collecting svgwrite (from svgling->prosodic)
#   Downloading svgwrite-1.4.3-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->prosodic) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.1.2->flask->prosodic) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.8.0->plotnine->prosodic) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.8.0->plotnine->prosodic) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.8.0->plotnine->prosodic) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.8.0->plotnine->prosodic) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.8.0->plotnine->prosodic) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.8.0->plotnine->prosodic) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.8.0->plotnine->prosodic) (3.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->prosodic) (0.7.0)
# Collecting bidict>=0.21.0 (from python-socketio>=5.0.2->flask-socketio->prosodic)
#   Downloading bidict-0.23.1-py3-none-any.whl.metadata (8.7 kB)
# Collecting python-engineio>=4.8.0 (from python-socketio>=5.0.2->flask-socketio->prosodic)
#   Downloading python_engineio-4.10.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.14.0->plotnine->prosodic) (1.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza->prosodic) (3.16.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza->prosodic) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza->prosodic) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.3.0->stanza->prosodic) (1.3.0)
# Collecting dill>=0.3.9 (from multiprocess->logmap->prosodic)
#   Using cached dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->stanza->prosodic) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->stanza->prosodic) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->stanza->prosodic) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->stanza->prosodic) (2024.8.30)
# Collecting clldutils>=1.7.3 (from segments->phonemizer->prosodic)
#   Downloading clldutils-3.24.0-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting csvw>=1.5.6 (from segments->phonemizer->prosodic)
#   Downloading csvw-3.5.1-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from clldutils>=1.7.3->segments->phonemizer->prosodic) (0.9.0)
# Collecting colorlog (from clldutils>=1.7.3->segments->phonemizer->prosodic)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting bibtexparser>=2.0.0b4 (from clldutils>=1.7.3->segments->phonemizer->prosodic)
#   Downloading bibtexparser-2.0.0b7-py3-none-any.whl.metadata (5.6 kB)
# Collecting pylatexenc (from clldutils>=1.7.3->segments->phonemizer->prosodic)
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 12.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from clldutils>=1.7.3->segments->phonemizer->prosodic) (3.7)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from clldutils>=1.7.3->segments->phonemizer->prosodic) (5.3.0)
# Collecting isodate (from csvw>=1.5.6->segments->phonemizer->prosodic)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting rfc3986<2 (from csvw>=1.5.6->segments->phonemizer->prosodic)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: uritemplate>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from csvw>=1.5.6->segments->phonemizer->prosodic) (4.1.1)
# Requirement already satisfied: babel in /usr/local/lib/python3.10/dist-packages (from csvw>=1.5.6->segments->phonemizer->prosodic) (2.16.0)
# Collecting language-tags (from csvw>=1.5.6->segments->phonemizer->prosodic)
#   Downloading language_tags-1.2.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting rdflib (from csvw>=1.5.6->segments->phonemizer->prosodic)
#   Downloading rdflib-7.1.1-py3-none-any.whl.metadata (11 kB)
# Collecting colorama (from csvw>=1.5.6->segments->phonemizer->prosodic)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from csvw>=1.5.6->segments->phonemizer->prosodic) (4.23.0)
# Collecting simple-websocket>=0.10.0 (from python-engineio>=4.8.0->python-socketio>=5.0.2->flask-socketio->prosodic)
#   Downloading simple_websocket-1.1.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting wsproto (from simple-websocket>=0.10.0->python-engineio>=4.8.0->python-socketio>=5.0.2->flask-socketio->prosodic)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer->prosodic) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer->prosodic) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->csvw>=1.5.6->segments->phonemizer->prosodic) (0.21.0)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from wsproto->simple-websocket>=0.10.0->python-engineio>=4.8.0->python-socketio>=5.0.2->flask-socketio->prosodic) (0.14.0)
# Downloading prosodic-2.0.8-py3-none-any.whl (6.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 2.6 MB/s eta 0:00:00
# Downloading Flask_SocketIO-5.4.1-py3-none-any.whl (18 kB)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.6 MB/s eta 0:00:00
# Downloading gevent-24.11.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 89.2 MB/s eta 0:00:00
# Downloading gevent_websocket-0.10.1-py3-none-any.whl (22 kB)
# Downloading logmap-0.0.3-py3-none-any.whl (18 kB)
# Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 5.0 MB/s eta 0:00:00
# Downloading multiset-3.2.0-py2.py3-none-any.whl (11 kB)
# Downloading munkres-1.1.4-py2.py3-none-any.whl (7.0 kB)
# Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Downloading phonemizer-3.3.0-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.8/103.8 kB 8.9 MB/s eta 0:00:00
# Downloading stanza-1.9.2-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 54.1 MB/s eta 0:00:00
# Downloading svgling-0.5.0-py3-none-any.whl (31 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 53.8 MB/s eta 0:00:00
# Downloading python_socketio-5.11.4-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 6.6 MB/s eta 0:00:00
# Downloading dlinfo-1.2.1-py3-none-any.whl (3.6 kB)
# Downloading emoji-2.14.0-py3-none-any.whl (586 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 586.9/586.9 kB 34.9 MB/s eta 0:00:00
# Downloading hashstash-0.2.11-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 46.8 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.6 MB/s eta 0:00:00
# Downloading lmdb-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 21.2 MB/s eta 0:00:00
# Downloading lz4-4.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 56.7 MB/s eta 0:00:00
# Downloading multiprocess-0.70.17-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.4 MB/s eta 0:00:00
# Downloading segments-2.2.1-py2.py3-none-any.whl (15 kB)
# Downloading svgwrite-1.4.3-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 5.4 MB/s eta 0:00:00
# Downloading zope.event-5.0-py3-none-any.whl (6.8 kB)
# Downloading zope.interface-7.1.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (254 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.2/254.2 kB 20.0 MB/s eta 0:00:00
# Downloading bidict-0.23.1-py3-none-any.whl (32 kB)
# Downloading clldutils-3.24.0-py2.py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 67.3 MB/s eta 0:00:00
# Downloading csvw-3.5.1-py2.py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 kB 5.2 MB/s eta 0:00:00
# Using cached dill-0.3.9-py3-none-any.whl (119 kB)
# Downloading python_engineio-4.10.1-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 4.7 MB/s eta 0:00:00
# Downloading bibtexparser-2.0.0b7-py3-none-any.whl (38 kB)
# Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Downloading simple_websocket-1.1.0-py3-none-any.whl (13 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading language_tags-1.2.0-py3-none-any.whl (213 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.4/213.4 kB 14.5 MB/s eta 0:00:00
# Downloading rdflib-7.1.1-py3-none-any.whl (562 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 562.4/562.4 kB 34.5 MB/s eta 0:00:00
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: gruut-ipa, langdetect, unicodecsv, ultradict, pylatexenc
#   Building wheel for gruut-ipa (setup.py) ... done
#   Created wheel for gruut-ipa: filename=gruut_ipa-0.13.0-py3-none-any.whl size=104873 sha256=b5a7b4e5a8f346eadfab0036c7be7d82366096cff64068d322a748580c916b1b
#   Stored in directory: /root/.cache/pip/wheels/7b/18/49/e4f500ecdf0babe757953f844e4d7cd1ea81c5503c09bfe984
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993222 sha256=532ee6d4d0864d1fd2ab09594e36b30018bd545c194fea7264aeef01b10e4b85
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
#   Building wheel for unicodecsv (setup.py) ... done
#   Created wheel for unicodecsv: filename=unicodecsv-0.14.1-py3-none-any.whl size=10744 sha256=469976313007745246ab8afa6680e38dbca20d8bc45402367e21e6d181d7c5aa
#   Stored in directory: /root/.cache/pip/wheels/9c/ea/66/8e45247b09052a933eb1a680b7c64802298faba58aac9b346b
#   Building wheel for ultradict (pyproject.toml) ... done
#   Created wheel for ultradict: filename=UltraDict-0.0.6-cp310-cp310-linux_x86_64.whl size=795287 sha256=a4b3a8da9b26467284a1105972a78e9cabd706c8a1890b3fc2513be8cf2ae243
#   Stored in directory: /root/.cache/pip/wheels/a8/4a/fe/356b3a03ba9fbde2c06298c6141e1bd0031210a1e530b36d06
#   Building wheel for pylatexenc (setup.py) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136816 sha256=851c4b67d88358a10dbaa85f3200d405d18959d322fe660ce74ce311325edaca
#   Stored in directory: /root/.cache/pip/wheels/d3/31/8b/e09b0386afd80cfc556c00408c9aeea5c35c4d484a9c762fd5
# Successfully built gruut-ipa langdetect unicodecsv ultradict pylatexenc
# Installing collected packages: unicodecsv, rfc3986, pylatexenc, munkres, lmdb, language-tags, dlinfo, zope.interface, zope.event, wsproto, ultradict, svgwrite, ordered-set, multiset, lz4, loguru, langdetect, jedi, isodate, humanfriendly, hashstash, gruut-ipa, ftfy, emoji, dill, colorlog, colorama, bidict, bibtexparser, svgling, simple-websocket, rdflib, multiprocess, gevent, clldutils, stanza, python-engineio, logmap, gevent-websocket, python-socketio, csvw, segments, flask-socketio, phonemizer, prosodic
# Successfully installed bibtexparser-2.0.0b7 bidict-0.23.1 clldutils-3.24.0 colorama-0.4.6 colorlog-6.9.0 csvw-3.5.1 dill-0.3.9 dlinfo-1.2.1 emoji-2.14.0 flask-socketio-5.4.1 ftfy-6.3.1 gevent-24.11.1 gevent-websocket-0.10.1 gruut-ipa-0.13.0 hashstash-0.2.11 humanfriendly-10.0 isodate-0.7.2 jedi-0.19.2 langdetect-1.0.9 language-tags-1.2.0 lmdb-1.5.1 logmap-0.0.3 loguru-0.7.2 lz4-4.3.3 multiprocess-0.70.17 multiset-3.2.0 munkres-1.1.4 ordered-set-4.1.0 phonemizer-3.3.0 prosodic-2.0.8 pylatexenc-2.10 python-engineio-4.10.1 python-socketio-5.11.4 rdflib-7.1.1 rfc3986-1.5.0 segments-2.2.1 simple-websocket-1.1.0 stanza-1.9.2 svgling-0.5.0 svgwrite-1.4.3 ultradict-0.0.6 unicodecsv-0.14.1 wsproto-1.2.0 zope.event-5.0 zope.interface-7.1.1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-6ebe7d95d796> in <cell line: 6>()
#       4 get_ipython().system('pip install -U prosodic')
#       5
# ----> 6 import prosodic
#       7 prosodic.logger.setLevel('ERROR')
#       8
#
# /usr/local/lib/python3.10/dist-packages/prosodic/__init__.py in <module>
# ----> 1 from .imports import *
#
# /usr/local/lib/python3.10/dist-packages/prosodic/imports.py in <module>
#      16 from langdetect import detect as detect_lang
#      17 import pandas as pd
# ---> 18 import nltk
#      19 import numpy as np
#      20 import ftfy
#
# /usr/local/lib/python3.10/dist-packages/nltk/__init__.py in <module>
#     136 from nltk.grammar import *
#     137 from nltk.probability import *
# --> 138 from nltk.text import *
#     139 from nltk.util import *
#     140 from nltk.jsontags import *
#
# /usr/local/lib/python3.10/dist-packages/nltk/text.py in <module>
#      28 from nltk.probability import ConditionalFreqDist as CFD
#      29 from nltk.probability import FreqDist
# ---> 30 from nltk.tokenize import sent_tokenize
#      31 from nltk.util import LazyConcatenation, cut_string, tokenwrap
#      32
#
# /usr/local/lib/python3.10/dist-packages/nltk/tokenize/__init__.py in <module>
#      64
#      65 from nltk.data import load
# ---> 66 from nltk.tokenize.casual import TweetTokenizer, casual_tokenize
#      67 from nltk.tokenize.destructive import NLTKWordTokenizer
#      68 from nltk.tokenize.legality_principle import LegalitySyllableTokenizer
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_spec(name, path, target)
#
# /usr/lib/python3.10/importlib/_bootstrap_external.py in find_spec(cls, fullname, path, target)
#
# /usr/lib/python3.10/importlib/_bootstrap_external.py in _get_spec(cls, fullname, path, target)
#
# /usr/lib/python3.10/importlib/_bootstrap_external.py in find_spec(self, fullname, target)
#
# /usr/lib/python3.10/importlib/_bootstrap_external.py in _fill_cache(self)
#
# KeyboardInterrupt:

# %%
linesProsodic = prosodic.Text(sonnet_129)

parse = linesProsodic.parse()


#parse = line.parse()

df = parse.stats()

df
# we are storing these results in a data frame so we can do more with them
# Out:
# [11.40s] Parsing lineparts:  97%|█████████▋| 32/33 [00:02<00:00, 14.07it/s]
#                                                                                                                                                                                                  parse_score  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                         parse_meter parse_stress sent_num sentpart_num
# 1          1        Th' expense of spirit in a waste of shame          1            1          th'.ex PENSE of SPI rit IN a WASTE of SHAME       --+-+-+-+-+ --+-+-+-+-+  1        1                     1.0
#            2        Is lust in action; and till action, lust           2            1          is LUST in AC tion and.till AC tion               -+-+---+-   -+-+---+-    1        1                     0.0
#            3        Is perjured, murd'rous, bloody, full of blame,     5            1          is PER jured MURD 'rous BLOO dy FULL of BLAME     -+-+-+-+-+  -+-+-+-+-+   1        3                     0.0
#            4        Savage, extreme, rude, cruel, not to trust,        9            1          SA vage ex TREME CR uel NOT to TRUST              +--++-+-+   +--++-+-+    1        7                     0.0
#            5        Enjoyed no sooner but despisèd straight,           14           1          en JOYED no SOO ner BUT des PISÈD straight        -+-+-+-+-   -+++---++    1        12                    3.0
# ...                                                                                                                                                                                                      ...
#            10       Had, having, and in quest to have, extreme;        21           1          had HA ving and.in QUEST to HAVE ex TREME         -+---+-+-+  -+---+-+-+   1        17                    0.0
#            11       A bliss in proof and proved, a very woe;           25           1          a BLISS in PROOF and PROVED a VE ry WOE           -+-+-+-+-+  -+-+-+-+-+   1        21                    0.0
#            12       Before, a joy proposed; behind, a dream.           27           1          be FORE a JOY pro POSED be HIND a DREAM           -+-+-+-+-+  -+-+-+-+-+   1        23                    0.0
#            13       All this the world well knows; yet none knows well 31           1          ALL this.the WORLD well KNOWS yet NONE knows WELL +--+-+-+-+  +--+++-+++   2        27                    2.0
#            14       To shun the heaven that leads men to this hell.    33           1          to SHUN the HEA ven THAT leads MEN to.this HELL   -+-+-+-+--+ -+-+-+++--+  2        28                    1.0
#
#                                                                                                                                                                                                  parse_num_viols  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                         parse_meter parse_stress sent_num sentpart_num
# 1          1        Th' expense of spirit in a waste of shame          1            1          th'.ex PENSE of SPI rit IN a WASTE of SHAME       --+-+-+-+-+ --+-+-+-+-+  1        1                           1
#            2        Is lust in action; and till action, lust           2            1          is LUST in AC tion and.till AC tion               -+-+---+-   -+-+---+-    1        1                           0
#            3        Is perjured, murd'rous, bloody, full of blame,     5            1          is PER jured MURD 'rous BLOO dy FULL of BLAME     -+-+-+-+-+  -+-+-+-+-+   1        3                           0
#            4        Savage, extreme, rude, cruel, not to trust,        9            1          SA vage ex TREME CR uel NOT to TRUST              +--++-+-+   +--++-+-+    1        7                           0
#            5        Enjoyed no sooner but despisèd straight,           14           1          en JOYED no SOO ner BUT des PISÈD straight        -+-+-+-+-   -+++---++    1        12                          3
# ...                                                                                                                                                                                                          ...
#            10       Had, having, and in quest to have, extreme;        21           1          had HA ving and.in QUEST to HAVE ex TREME         -+---+-+-+  -+---+-+-+   1        17                          0
#            11       A bliss in proof and proved, a very woe;           25           1          a BLISS in PROOF and PROVED a VE ry WOE           -+-+-+-+-+  -+-+-+-+-+   1        21                          0
#            12       Before, a joy proposed; behind, a dream.           27           1          be FORE a JOY pro POSED be HIND a DREAM           -+-+-+-+-+  -+-+-+-+-+   1        23                          0
#            13       All this the world well knows; yet none knows well 31           1          ALL this.the WORLD well KNOWS yet NONE knows WELL +--+-+-+-+  +--+++-+++   2        27                          2
#            14       To shun the heaven that leads men to this hell.    33           1          to SHUN the HEA ven THAT leads MEN to.this HELL   -+-+-+-+--+ -+-+-+++--+  2        28                          1
#
#                                                                                                                                                                                                  parse_ambig  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                         parse_meter parse_stress sent_num sentpart_num
# 1          1        Th' expense of spirit in a waste of shame          1            1          th'.ex PENSE of SPI rit IN a WASTE of SHAME       --+-+-+-+-+ --+-+-+-+-+  1        1                       2
#            2        Is lust in action; and till action, lust           2            1          is LUST in AC tion and.till AC tion               -+-+---+-   -+-+---+-    1        1                       1
#            3        Is perjured, murd'rous, bloody, full of blame,     5            1          is PER jured MURD 'rous BLOO dy FULL of BLAME     -+-+-+-+-+  -+-+-+-+-+   1        3                       1
#            4        Savage, extreme, rude, cruel, not to trust,        9            1          SA vage ex TREME CR uel NOT to TRUST              +--++-+-+   +--++-+-+    1        7                       4
#            5        Enjoyed no sooner but despisèd straight,           14           1          en JOYED no SOO ner BUT des PISÈD straight        -+-+-+-+-   -+++---++    1        12                      2
# ...                                                                                                                                                                                                      ...
#            10       Had, having, and in quest to have, extreme;        21           1          had HA ving and.in QUEST to HAVE ex TREME         -+---+-+-+  -+---+-+-+   1        17                      4
#            11       A bliss in proof and proved, a very woe;           25           1          a BLISS in PROOF and PROVED a VE ry WOE           -+-+-+-+-+  -+-+-+-+-+   1        21                      1
#            12       Before, a joy proposed; behind, a dream.           27           1          be FORE a JOY pro POSED be HIND a DREAM           -+-+-+-+-+  -+-+-+-+-+   1        23                      2
#            13       All this the world well knows; yet none knows well 31           1          ALL this.the WORLD well KNOWS yet NONE knows WELL +--+-+-+-+  +--+++-+++   2        27                      1
#            14       To shun the heaven that leads men to this hell.    33           1          to SHUN the HEA ven THAT leads MEN to.this HELL   -+-+-+-+--+ -+-+-+++--+  2        28                      2
#
#                                                                                                                                                                                                  parse_is_bounded  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                         parse_meter parse_stress sent_num sentpart_num
# 1          1        Th' expense of spirit in a waste of shame          1            1          th'.ex PENSE of SPI rit IN a WASTE of SHAME       --+-+-+-+-+ --+-+-+-+-+  1        1                            0
#            2        Is lust in action; and till action, lust           2            1          is LUST in AC tion and.till AC tion               -+-+---+-   -+-+---+-    1        1                            0
#            3        Is perjured, murd'rous, bloody, full of blame,     5            1          is PER jured MURD 'rous BLOO dy FULL of BLAME     -+-+-+-+-+  -+-+-+-+-+   1        3                            0
#            4        Savage, extreme, rude, cruel, not to trust,        9            1          SA vage ex TREME CR uel NOT to TRUST              +--++-+-+   +--++-+-+    1        7                            0
#            5        Enjoyed no sooner but despisèd straight,           14           1          en JOYED no SOO ner BUT des PISÈD straight        -+-+-+-+-   -+++---++    1        12                           0
# ...                                                                                                                                                                                                           ...
#            10       Had, having, and in quest to have, extreme;        21           1          had HA ving and.in QUEST to HAVE ex TREME         -+---+-+-+  -+---+-+-+   1        17                           0
#            11       A bliss in proof and proved, a very woe;           25           1          a BLISS in PROOF and PROVED a VE ry WOE           -+-+-+-+-+  -+-+-+-+-+   1        21                           0
#            12       Before, a joy proposed; behind, a dream.           27           1          be FORE a JOY pro POSED be HIND a DREAM           -+-+-+-+-+  -+-+-+-+-+   1        23                           0
#            13       All this the world well knows; yet none knows well 31           1          ALL this.the WORLD well KNOWS yet NONE knows WELL +--+-+-+-+  +--+++-+++   2        27                           0
#            14       To shun the heaven that leads men to this hell.    33           1          to SHUN the HEA ven THAT leads MEN to.this HELL   -+-+-+-+--+ -+-+-+++--+  2        28                           0
#
#                                                                                                                                                                                                  parse_num_sylls  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                         parse_meter parse_stress sent_num sentpart_num
# 1          1        Th' expense of spirit in a waste of shame          1            1          th'.ex PENSE of SPI rit IN a WASTE of SHAME       --+-+-+-+-+ --+-+-+-+-+  1        1                          11
#            2        Is lust in action; and till action, lust           2            1          is LUST in AC tion and.till AC tion               -+-+---+-   -+-+---+-    1        1                           9
#            3        Is perjured, murd'rous, bloody, full of blame,     5            1          is PER jured MURD 'rous BLOO dy FULL of BLAME     -+-+-+-+-+  -+-+-+-+-+   1        3                          10
#            4        Savage, extreme, rude, cruel, not to trust,        9            1          SA vage ex TREME CR uel NOT to TRUST              +--++-+-+   +--++-+-+    1        7                           9
#            5        Enjoyed no sooner but despisèd straight,           14           1          en JOYED no SOO ner BUT des PISÈD straight        -+-+-+-+-   -+++---++    1        12                          9
# ...                                                                                                                                                                                                          ...
#            10       Had, having, and in quest to have, extreme;        21           1          had HA ving and.in QUEST to HAVE ex TREME         -+---+-+-+  -+---+-+-+   1        17                         10
#            11       A bliss in proof and proved, a very woe;           25           1          a BLISS in PROOF and PROVED a VE ry WOE           -+-+-+-+-+  -+-+-+-+-+   1        21                         10
#            12       Before, a joy proposed; behind, a dream.           27           1          be FORE a JOY pro POSED be HIND a DREAM           -+-+-+-+-+  -+-+-+-+-+   1        23                         10
#            13       All this the world well knows; yet none knows well 31           1          ALL this.the WORLD well KNOWS yet NONE knows WELL +--+-+-+-+  +--+++-+++   2        27                         10
#            14       To shun the heaven that leads men to this hell.    33           1          to SHUN the HEA ven THAT leads MEN to.this HELL   -+-+-+-+--+ -+-+-+++--+  2        28                         11
#
#                                                                                                                                                                                                  parse_num_words  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                         parse_meter parse_stress sent_num sentpart_num
# 1          1        Th' expense of spirit in a waste of shame          1            1          th'.ex PENSE of SPI rit IN a WASTE of SHAME       --+-+-+-+-+ --+-+-+-+-+  1        1                           9
#            2        Is lust in action; and till action, lust           2            1          is LUST in AC tion and.till AC tion               -+-+---+-   -+-+---+-    1        1                           7
#            3        Is perjured, murd'rous, bloody, full of blame,     5            1          is PER jured MURD 'rous BLOO dy FULL of BLAME     -+-+-+-+-+  -+-+-+-+-+   1        3                           7
#            4        Savage, extreme, rude, cruel, not to trust,        9            1          SA vage ex TREME CR uel NOT to TRUST              +--++-+-+   +--++-+-+    1        7                           6
#            5        Enjoyed no sooner but despisèd straight,           14           1          en JOYED no SOO ner BUT des PISÈD straight        -+-+-+-+-   -+++---++    1        12                          6
# ...                                                                                                                                                                                                          ...
#            10       Had, having, and in quest to have, extreme;        21           1          had HA ving and.in QUEST to HAVE ex TREME         -+---+-+-+  -+---+-+-+   1        17                          8
#            11       A bliss in proof and proved, a very woe;           25           1          a BLISS in PROOF and PROVED a VE ry WOE           -+-+-+-+-+  -+-+-+-+-+   1        21                          9
#            12       Before, a joy proposed; behind, a dream.           27           1          be FORE a JOY pro POSED be HIND a DREAM           -+-+-+-+-+  -+-+-+-+-+   1        23                          7
#            13       All this the world well knows; yet none knows well 31           1          ALL this.the WORLD well KNOWS yet NONE knows WELL +--+-+-+-+  +--+++-+++   2        27                         10
#            14       To shun the heaven that leads men to this hell.    33           1          to SHUN the HEA ven THAT leads MEN to.this HELL   -+-+-+-+--+ -+-+-+++--+  2        28                         10
#
#                                                                                                                                                                                                  *w_peak  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                         parse_meter parse_stress sent_num sentpart_num
# 1          1        Th' expense of spirit in a waste of shame          1            1          th'.ex PENSE of SPI rit IN a WASTE of SHAME       --+-+-+-+-+ --+-+-+-+-+  1        1                 0.0
#            2        Is lust in action; and till action, lust           2            1          is LUST in AC tion and.till AC tion               -+-+---+-   -+-+---+-    1        1                 0.0
#            3        Is perjured, murd'rous, bloody, full of blame,     5            1          is PER jured MURD 'rous BLOO dy FULL of BLAME     -+-+-+-+-+  -+-+-+-+-+   1        3                 0.0
#            4        Savage, extreme, rude, cruel, not to trust,        9            1          SA vage ex TREME CR uel NOT to TRUST              +--++-+-+   +--++-+-+    1        7                 0.0
#            5        Enjoyed no sooner but despisèd straight,           14           1          en JOYED no SOO ner BUT des PISÈD straight        -+-+-+-+-   -+++---++    1        12                0.0
# ...                                                                                                                                                                                                  ...
#            10       Had, having, and in quest to have, extreme;        21           1          had HA ving and.in QUEST to HAVE ex TREME         -+---+-+-+  -+---+-+-+   1        17                0.0
#            11       A bliss in proof and proved, a very woe;           25           1          a BLISS in PROOF and PROVED a VE ry WOE           -+-+-+-+-+  -+-+-+-+-+   1        21                0.0
#            12       Before, a joy proposed; behind, a dream.           27           1          be FORE a JOY pro POSED be HIND a DREAM           -+-+-+-+-+  -+-+-+-+-+   1        23                0.0
#            13       All this the world well knows; yet none knows well 31           1          ALL this.the WORLD well KNOWS yet NONE knows WELL +--+-+-+-+  +--+++-+++   2        27                0.0
#            14       To shun the heaven that leads men to this hell.    33           1          to SHUN the HEA ven THAT leads MEN to.this HELL   -+-+-+-+--+ -+-+-+++--+  2        28                0.0
#
#                                                                                                                                                                                                  *w_stress  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                         parse_meter parse_stress sent_num sentpart_num
# 1          1        Th' expense of spirit in a waste of shame          1            1          th'.ex PENSE of SPI rit IN a WASTE of SHAME       --+-+-+-+-+ --+-+-+-+-+  1        1                   0.0
#            2        Is lust in action; and till action, lust           2            1          is LUST in AC tion and.till AC tion               -+-+---+-   -+-+---+-    1        1                   0.0
#            3        Is perjured, murd'rous, bloody, full of blame,     5            1          is PER jured MURD 'rous BLOO dy FULL of BLAME     -+-+-+-+-+  -+-+-+-+-+   1        3                   0.0
#            4        Savage, extreme, rude, cruel, not to trust,        9            1          SA vage ex TREME CR uel NOT to TRUST              +--++-+-+   +--++-+-+    1        7                   0.0
#            5        Enjoyed no sooner but despisèd straight,           14           1          en JOYED no SOO ner BUT des PISÈD straight        -+-+-+-+-   -+++---++    1        12                  2.0
# ...                                                                                                                                                                                                    ...
#            10       Had, having, and in quest to have, extreme;        21           1          had HA ving and.in QUEST to HAVE ex TREME         -+---+-+-+  -+---+-+-+   1        17                  0.0
#            11       A bliss in proof and proved, a very woe;           25           1          a BLISS in PROOF and PROVED a VE ry WOE           -+-+-+-+-+  -+-+-+-+-+   1        21                  0.0
#            12       Before, a joy proposed; behind, a dream.           27           1          be FORE a JOY pro POSED be HIND a DREAM           -+-+-+-+-+  -+-+-+-+-+   1        23                  0.0
#            13       All this the world well knows; yet none knows well 31           1          ALL this.the WORLD well KNOWS yet NONE knows WELL +--+-+-+-+  +--+++-+++   2        27                  2.0
#            14       To shun the heaven that leads men to this hell.    33           1          to SHUN the HEA ven THAT leads MEN to.this HELL   -+-+-+-+--+ -+-+-+++--+  2        28                  1.0
#
#                                                                                                                                                                                                  *s_unstress  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                         parse_meter parse_stress sent_num sentpart_num
# 1          1        Th' expense of spirit in a waste of shame          1            1          th'.ex PENSE of SPI rit IN a WASTE of SHAME       --+-+-+-+-+ --+-+-+-+-+  1        1                     0.0
#            2        Is lust in action; and till action, lust           2            1          is LUST in AC tion and.till AC tion               -+-+---+-   -+-+---+-    1        1                     0.0
#            3        Is perjured, murd'rous, bloody, full of blame,     5            1          is PER jured MURD 'rous BLOO dy FULL of BLAME     -+-+-+-+-+  -+-+-+-+-+   1        3                     0.0
#            4        Savage, extreme, rude, cruel, not to trust,        9            1          SA vage ex TREME CR uel NOT to TRUST              +--++-+-+   +--++-+-+    1        7                     0.0
#            5        Enjoyed no sooner but despisèd straight,           14           1          en JOYED no SOO ner BUT des PISÈD straight        -+-+-+-+-   -+++---++    1        12                    1.0
# ...                                                                                                                                                                                                      ...
#            10       Had, having, and in quest to have, extreme;        21           1          had HA ving and.in QUEST to HAVE ex TREME         -+---+-+-+  -+---+-+-+   1        17                    0.0
#            11       A bliss in proof and proved, a very woe;           25           1          a BLISS in PROOF and PROVED a VE ry WOE           -+-+-+-+-+  -+-+-+-+-+   1        21                    0.0
#            12       Before, a joy proposed; behind, a dream.           27           1          be FORE a JOY pro POSED be HIND a DREAM           -+-+-+-+-+  -+-+-+-+-+   1        23                    0.0
#            13       All this the world well knows; yet none knows well 31           1          ALL this.the WORLD well KNOWS yet NONE knows WELL +--+-+-+-+  +--+++-+++   2        27                    0.0
#            14       To shun the heaven that leads men to this hell.    33           1          to SHUN the HEA ven THAT leads MEN to.this HELL   -+-+-+-+--+ -+-+-+++--+  2        28                    0.0
#
#                                                                                                                                                                                                  *unres_across  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                         parse_meter parse_stress sent_num sentpart_num
# 1          1        Th' expense of spirit in a waste of shame          1            1          th'.ex PENSE of SPI rit IN a WASTE of SHAME       --+-+-+-+-+ --+-+-+-+-+  1        1                       1.0
#            2        Is lust in action; and till action, lust           2            1          is LUST in AC tion and.till AC tion               -+-+---+-   -+-+---+-    1        1                       0.0
#            3        Is perjured, murd'rous, bloody, full of blame,     5            1          is PER jured MURD 'rous BLOO dy FULL of BLAME     -+-+-+-+-+  -+-+-+-+-+   1        3                       0.0
#            4        Savage, extreme, rude, cruel, not to trust,        9            1          SA vage ex TREME CR uel NOT to TRUST              +--++-+-+   +--++-+-+    1        7                       0.0
#            5        Enjoyed no sooner but despisèd straight,           14           1          en JOYED no SOO ner BUT des PISÈD straight        -+-+-+-+-   -+++---++    1        12                      0.0
# ...                                                                                                                                                                                                        ...
#            10       Had, having, and in quest to have, extreme;        21           1          had HA ving and.in QUEST to HAVE ex TREME         -+---+-+-+  -+---+-+-+   1        17                      0.0
#            11       A bliss in proof and proved, a very woe;           25           1          a BLISS in PROOF and PROVED a VE ry WOE           -+-+-+-+-+  -+-+-+-+-+   1        21                      0.0
#            12       Before, a joy proposed; behind, a dream.           27           1          be FORE a JOY pro POSED be HIND a DREAM           -+-+-+-+-+  -+-+-+-+-+   1        23                      0.0
#            13       All this the world well knows; yet none knows well 31           1          ALL this.the WORLD well KNOWS yet NONE knows WELL +--+-+-+-+  +--+++-+++   2        27                      0.0
#            14       To shun the heaven that leads men to this hell.    33           1          to SHUN the HEA ven THAT leads MEN to.this HELL   -+-+-+-+--+ -+-+-+++--+  2        28                      0.0
#
#                                                                                                                                                                                                  ...  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                         parse_meter parse_stress sent_num sentpart_num  ...
# 1          1        Th' expense of spirit in a waste of shame          1            1          th'.ex PENSE of SPI rit IN a WASTE of SHAME       --+-+-+-+-+ --+-+-+-+-+  1        1             ...
#            2        Is lust in action; and till action, lust           2            1          is LUST in AC tion and.till AC tion               -+-+---+-   -+-+---+-    1        1             ...
#            3        Is perjured, murd'rous, bloody, full of blame,     5            1          is PER jured MURD 'rous BLOO dy FULL of BLAME     -+-+-+-+-+  -+-+-+-+-+   1        3             ...
#            4        Savage, extreme, rude, cruel, not to trust,        9            1          SA vage ex TREME CR uel NOT to TRUST              +--++-+-+   +--++-+-+    1        7             ...
#            5        Enjoyed no sooner but despisèd straight,           14           1          en JOYED no SOO ner BUT des PISÈD straight        -+-+-+-+-   -+++---++    1        12            ...
# ...                                                                                                                                                                                              ...
#            10       Had, having, and in quest to have, extreme;        21           1          had HA ving and.in QUEST to HAVE ex TREME         -+---+-+-+  -+---+-+-+   1        17            ...
#            11       A bliss in proof and proved, a very woe;           25           1          a BLISS in PROOF and PROVED a VE ry WOE           -+-+-+-+-+  -+-+-+-+-+   1        21            ...
#            12       Before, a joy proposed; behind, a dream.           27           1          be FORE a JOY pro POSED be HIND a DREAM           -+-+-+-+-+  -+-+-+-+-+   1        23            ...
#            13       All this the world well knows; yet none knows well 31           1          ALL this.the WORLD well KNOWS yet NONE knows WELL +--+-+-+-+  +--+++-+++   2        27            ...
#            14       To shun the heaven that leads men to this hell.    33           1          to SHUN the HEA ven THAT leads MEN to.this HELL   -+-+-+-+--+ -+-+-+++--+  2        28            ...
#
#                                                                                                                                                                                                  *total_sylls  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                         parse_meter parse_stress sent_num sentpart_num
# 1          1        Th' expense of spirit in a waste of shame          1            1          th'.ex PENSE of SPI rit IN a WASTE of SHAME       --+-+-+-+-+ --+-+-+-+-+  1        1                        1
#            2        Is lust in action; and till action, lust           2            1          is LUST in AC tion and.till AC tion               -+-+---+-   -+-+---+-    1        1                        0
#            3        Is perjured, murd'rous, bloody, full of blame,     5            1          is PER jured MURD 'rous BLOO dy FULL of BLAME     -+-+-+-+-+  -+-+-+-+-+   1        3                        0
#            4        Savage, extreme, rude, cruel, not to trust,        9            1          SA vage ex TREME CR uel NOT to TRUST              +--++-+-+   +--++-+-+    1        7                        0
#            5        Enjoyed no sooner but despisèd straight,           14           1          en JOYED no SOO ner BUT des PISÈD straight        -+-+-+-+-   -+++---++    1        12                       3
# ...                                                                                                                                                                                                       ...
#            10       Had, having, and in quest to have, extreme;        21           1          had HA ving and.in QUEST to HAVE ex TREME         -+---+-+-+  -+---+-+-+   1        17                       0
#            11       A bliss in proof and proved, a very woe;           25           1          a BLISS in PROOF and PROVED a VE ry WOE           -+-+-+-+-+  -+-+-+-+-+   1        21                       0
#            12       Before, a joy proposed; behind, a dream.           27           1          be FORE a JOY pro POSED be HIND a DREAM           -+-+-+-+-+  -+-+-+-+-+   1        23                       0
#            13       All this the world well knows; yet none knows well 31           1          ALL this.the WORLD well KNOWS yet NONE knows WELL +--+-+-+-+  +--+++-+++   2        27                       2
#            14       To shun the heaven that leads men to this hell.    33           1          to SHUN the HEA ven THAT leads MEN to.this HELL   -+-+-+-+--+ -+-+-+++--+  2        28                       1
#
#                                                                                                                                                                                                  *total  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                         parse_meter parse_stress sent_num sentpart_num
# 1          1        Th' expense of spirit in a waste of shame          1            1          th'.ex PENSE of SPI rit IN a WASTE of SHAME       --+-+-+-+-+ --+-+-+-+-+  1        1                  1
#            2        Is lust in action; and till action, lust           2            1          is LUST in AC tion and.till AC tion               -+-+---+-   -+-+---+-    1        1                  0
#            3        Is perjured, murd'rous, bloody, full of blame,     5            1          is PER jured MURD 'rous BLOO dy FULL of BLAME     -+-+-+-+-+  -+-+-+-+-+   1        3                  0
#            4        Savage, extreme, rude, cruel, not to trust,        9            1          SA vage ex TREME CR uel NOT to TRUST              +--++-+-+   +--++-+-+    1        7                  0
#            5        Enjoyed no sooner but despisèd straight,           14           1          en JOYED no SOO ner BUT des PISÈD straight        -+-+-+-+-   -+++---++    1        12                 3
# ...                                                                                                                                                                                                 ...
#            10       Had, having, and in quest to have, extreme;        21           1          had HA ving and.in QUEST to HAVE ex TREME         -+---+-+-+  -+---+-+-+   1        17                 0
#            11       A bliss in proof and proved, a very woe;           25           1          a BLISS in PROOF and PROVED a VE ry WOE           -+-+-+-+-+  -+-+-+-+-+   1        21                 0
#            12       Before, a joy proposed; behind, a dream.           27           1          be FORE a JOY pro POSED be HIND a DREAM           -+-+-+-+-+  -+-+-+-+-+   1        23                 0
#            13       All this the world well knows; yet none knows well 31           1          ALL this.the WORLD well KNOWS yet NONE knows WELL +--+-+-+-+  +--+++-+++   2        27                 2
#            14       To shun the heaven that leads men to this hell.    33           1          to SHUN the HEA ven THAT leads MEN to.this HELL   -+-+-+-+--+ -+-+-+++--+  2        28                 1
#
#                                                                                                                                                                                                  *w_peak_norm  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                         parse_meter parse_stress sent_num sentpart_num
# 1          1        Th' expense of spirit in a waste of shame          1            1          th'.ex PENSE of SPI rit IN a WASTE of SHAME       --+-+-+-+-+ --+-+-+-+-+  1        1                      0.0
#            2        Is lust in action; and till action, lust           2            1          is LUST in AC tion and.till AC tion               -+-+---+-   -+-+---+-    1        1                      0.0
#            3        Is perjured, murd'rous, bloody, full of blame,     5            1          is PER jured MURD 'rous BLOO dy FULL of BLAME     -+-+-+-+-+  -+-+-+-+-+   1        3                      0.0
#            4        Savage, extreme, rude, cruel, not to trust,        9            1          SA vage ex TREME CR uel NOT to TRUST              +--++-+-+   +--++-+-+    1        7                      0.0
#            5        Enjoyed no sooner but despisèd straight,           14           1          en JOYED no SOO ner BUT des PISÈD straight        -+-+-+-+-   -+++---++    1        12                     0.0
# ...                                                                                                                                                                                                       ...
#            10       Had, having, and in quest to have, extreme;        21           1          had HA ving and.in QUEST to HAVE ex TREME         -+---+-+-+  -+---+-+-+   1        17                     0.0
#            11       A bliss in proof and proved, a very woe;           25           1          a BLISS in PROOF and PROVED a VE ry WOE           -+-+-+-+-+  -+-+-+-+-+   1        21                     0.0
#            12       Before, a joy proposed; behind, a dream.           27           1          be FORE a JOY pro POSED be HIND a DREAM           -+-+-+-+-+  -+-+-+-+-+   1        23                     0.0
#            13       All this the world well knows; yet none knows well 31           1          ALL this.the WORLD well KNOWS yet NONE knows WELL +--+-+-+-+  +--+++-+++   2        27                     0.0
#            14       To shun the heaven that leads men to this hell.    33           1          to SHUN the HEA ven THAT leads MEN to.this HELL   -+-+-+-+--+ -+-+-+++--+  2        28                     0.0
#
#                                                                                                                                                                                                  *w_stress_norm  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                         parse_meter parse_stress sent_num sentpart_num
# 1          1        Th' expense of spirit in a waste of shame          1            1          th'.ex PENSE of SPI rit IN a WASTE of SHAME       --+-+-+-+-+ --+-+-+-+-+  1        1                   0.000000
#            2        Is lust in action; and till action, lust           2            1          is LUST in AC tion and.till AC tion               -+-+---+-   -+-+---+-    1        1                   0.000000
#            3        Is perjured, murd'rous, bloody, full of blame,     5            1          is PER jured MURD 'rous BLOO dy FULL of BLAME     -+-+-+-+-+  -+-+-+-+-+   1        3                   0.000000
#            4        Savage, extreme, rude, cruel, not to trust,        9            1          SA vage ex TREME CR uel NOT to TRUST              +--++-+-+   +--++-+-+    1        7                   0.000000
#            5        Enjoyed no sooner but despisèd straight,           14           1          en JOYED no SOO ner BUT des PISÈD straight        -+-+-+-+-   -+++---++    1        12                  0.222222
# ...                                                                                                                                                                                                         ...
#            10       Had, having, and in quest to have, extreme;        21           1          had HA ving and.in QUEST to HAVE ex TREME         -+---+-+-+  -+---+-+-+   1        17                  0.000000
#            11       A bliss in proof and proved, a very woe;           25           1          a BLISS in PROOF and PROVED a VE ry WOE           -+-+-+-+-+  -+-+-+-+-+   1        21                  0.000000
#            12       Before, a joy proposed; behind, a dream.           27           1          be FORE a JOY pro POSED be HIND a DREAM           -+-+-+-+-+  -+-+-+-+-+   1        23                  0.000000
#            13       All this the world well knows; yet none knows well 31           1          ALL this.the WORLD well KNOWS yet NONE knows WELL +--+-+-+-+  +--+++-+++   2        27                  0.200000
#            14       To shun the heaven that leads men to this hell.    33           1          to SHUN the HEA ven THAT leads MEN to.this HELL   -+-+-+-+--+ -+-+-+++--+  2        28                  0.090909
#
#                                                                                                                                                                                                  *s_unstress_norm  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                         parse_meter parse_stress sent_num sentpart_num
# 1          1        Th' expense of spirit in a waste of shame          1            1          th'.ex PENSE of SPI rit IN a WASTE of SHAME       --+-+-+-+-+ --+-+-+-+-+  1        1                     0.000000
#            2        Is lust in action; and till action, lust           2            1          is LUST in AC tion and.till AC tion               -+-+---+-   -+-+---+-    1        1                     0.000000
#            3        Is perjured, murd'rous, bloody, full of blame,     5            1          is PER jured MURD 'rous BLOO dy FULL of BLAME     -+-+-+-+-+  -+-+-+-+-+   1        3                     0.000000
#            4        Savage, extreme, rude, cruel, not to trust,        9            1          SA vage ex TREME CR uel NOT to TRUST              +--++-+-+   +--++-+-+    1        7                     0.000000
#            5        Enjoyed no sooner but despisèd straight,           14           1          en JOYED no SOO ner BUT des PISÈD straight        -+-+-+-+-   -+++---++    1        12                    0.111111
# ...                                                                                                                                                                                                           ...
#            10       Had, having, and in quest to have, extreme;        21           1          had HA ving and.in QUEST to HAVE ex TREME         -+---+-+-+  -+---+-+-+   1        17                    0.000000
#            11       A bliss in proof and proved, a very woe;           25           1          a BLISS in PROOF and PROVED a VE ry WOE           -+-+-+-+-+  -+-+-+-+-+   1        21                    0.000000
#            12       Before, a joy proposed; behind, a dream.           27           1          be FORE a JOY pro POSED be HIND a DREAM           -+-+-+-+-+  -+-+-+-+-+   1        23                    0.000000
#            13       All this the world well knows; yet none knows well 31           1          ALL this.the WORLD well KNOWS yet NONE knows WELL +--+-+-+-+  +--+++-+++   2        27                    0.000000
#            14       To shun the heaven that leads men to this hell.    33           1          to SHUN the HEA ven THAT leads MEN to.this HELL   -+-+-+-+--+ -+-+-+++--+  2        28                    0.000000
#
#                                                                                                                                                                                                  *unres_across_norm  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                         parse_meter parse_stress sent_num sentpart_num
# 1          1        Th' expense of spirit in a waste of shame          1            1          th'.ex PENSE of SPI rit IN a WASTE of SHAME       --+-+-+-+-+ --+-+-+-+-+  1        1                       0.090909
#            2        Is lust in action; and till action, lust           2            1          is LUST in AC tion and.till AC tion               -+-+---+-   -+-+---+-    1        1                       0.000000
#            3        Is perjured, murd'rous, bloody, full of blame,     5            1          is PER jured MURD 'rous BLOO dy FULL of BLAME     -+-+-+-+-+  -+-+-+-+-+   1        3                       0.000000
#            4        Savage, extreme, rude, cruel, not to trust,        9            1          SA vage ex TREME CR uel NOT to TRUST              +--++-+-+   +--++-+-+    1        7                       0.000000
#            5        Enjoyed no sooner but despisèd straight,           14           1          en JOYED no SOO ner BUT des PISÈD straight        -+-+-+-+-   -+++---++    1        12                      0.000000
# ...                                                                                                                                                                                                             ...
#            10       Had, having, and in quest to have, extreme;        21           1          had HA ving and.in QUEST to HAVE ex TREME         -+---+-+-+  -+---+-+-+   1        17                      0.000000
#            11       A bliss in proof and proved, a very woe;           25           1          a BLISS in PROOF and PROVED a VE ry WOE           -+-+-+-+-+  -+-+-+-+-+   1        21                      0.000000
#            12       Before, a joy proposed; behind, a dream.           27           1          be FORE a JOY pro POSED be HIND a DREAM           -+-+-+-+-+  -+-+-+-+-+   1        23                      0.000000
#            13       All this the world well knows; yet none knows well 31           1          ALL this.the WORLD well KNOWS yet NONE knows WELL +--+-+-+-+  +--+++-+++   2        27                      0.000000
#            14       To shun the heaven that leads men to this hell.    33           1          to SHUN the HEA ven THAT leads MEN to.this HELL   -+-+-+-+--+ -+-+-+++--+  2        28                      0.000000
#
#                                                                                                                                                                                                  *unres_within_norm  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                         parse_meter parse_stress sent_num sentpart_num
# 1          1        Th' expense of spirit in a waste of shame          1            1          th'.ex PENSE of SPI rit IN a WASTE of SHAME       --+-+-+-+-+ --+-+-+-+-+  1        1                            0.0
#            2        Is lust in action; and till action, lust           2            1          is LUST in AC tion and.till AC tion               -+-+---+-   -+-+---+-    1        1                            0.0
#            3        Is perjured, murd'rous, bloody, full of blame,     5            1          is PER jured MURD 'rous BLOO dy FULL of BLAME     -+-+-+-+-+  -+-+-+-+-+   1        3                            0.0
#            4        Savage, extreme, rude, cruel, not to trust,        9            1          SA vage ex TREME CR uel NOT to TRUST              +--++-+-+   +--++-+-+    1        7                            0.0
#            5        Enjoyed no sooner but despisèd straight,           14           1          en JOYED no SOO ner BUT des PISÈD straight        -+-+-+-+-   -+++---++    1        12                           0.0
# ...                                                                                                                                                                                                             ...
#            10       Had, having, and in quest to have, extreme;        21           1          had HA ving and.in QUEST to HAVE ex TREME         -+---+-+-+  -+---+-+-+   1        17                           0.0
#            11       A bliss in proof and proved, a very woe;           25           1          a BLISS in PROOF and PROVED a VE ry WOE           -+-+-+-+-+  -+-+-+-+-+   1        21                           0.0
#            12       Before, a joy proposed; behind, a dream.           27           1          be FORE a JOY pro POSED be HIND a DREAM           -+-+-+-+-+  -+-+-+-+-+   1        23                           0.0
#            13       All this the world well knows; yet none knows well 31           1          ALL this.the WORLD well KNOWS yet NONE knows WELL +--+-+-+-+  +--+++-+++   2        27                           0.0
#            14       To shun the heaven that leads men to this hell.    33           1          to SHUN the HEA ven THAT leads MEN to.this HELL   -+-+-+-+--+ -+-+-+++--+  2        28                           0.0
#
#                                                                                                                                                                                                  *foot_size_norm  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                         parse_meter parse_stress sent_num sentpart_num
# 1          1        Th' expense of spirit in a waste of shame          1            1          th'.ex PENSE of SPI rit IN a WASTE of SHAME       --+-+-+-+-+ --+-+-+-+-+  1        1                         0.0
#            2        Is lust in action; and till action, lust           2            1          is LUST in AC tion and.till AC tion               -+-+---+-   -+-+---+-    1        1                         0.0
#            3        Is perjured, murd'rous, bloody, full of blame,     5            1          is PER jured MURD 'rous BLOO dy FULL of BLAME     -+-+-+-+-+  -+-+-+-+-+   1        3                         0.0
#            4        Savage, extreme, rude, cruel, not to trust,        9            1          SA vage ex TREME CR uel NOT to TRUST              +--++-+-+   +--++-+-+    1        7                         0.0
#            5        Enjoyed no sooner but despisèd straight,           14           1          en JOYED no SOO ner BUT des PISÈD straight        -+-+-+-+-   -+++---++    1        12                        0.0
# ...                                                                                                                                                                                                          ...
#            10       Had, having, and in quest to have, extreme;        21           1          had HA ving and.in QUEST to HAVE ex TREME         -+---+-+-+  -+---+-+-+   1        17                        0.0
#            11       A bliss in proof and proved, a very woe;           25           1          a BLISS in PROOF and PROVED a VE ry WOE           -+-+-+-+-+  -+-+-+-+-+   1        21                        0.0
#            12       Before, a joy proposed; behind, a dream.           27           1          be FORE a JOY pro POSED be HIND a DREAM           -+-+-+-+-+  -+-+-+-+-+   1        23                        0.0
#            13       All this the world well knows; yet none knows well 31           1          ALL this.the WORLD well KNOWS yet NONE knows WELL +--+-+-+-+  +--+++-+++   2        27                        0.0
#            14       To shun the heaven that leads men to this hell.    33           1          to SHUN the HEA ven THAT leads MEN to.this HELL   -+-+-+-+--+ -+-+-+++--+  2        28                        0.0
#
#                                                                                                                                                                                                  *total_sylls_norm  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                         parse_meter parse_stress sent_num sentpart_num
# 1          1        Th' expense of spirit in a waste of shame          1            1          th'.ex PENSE of SPI rit IN a WASTE of SHAME       --+-+-+-+-+ --+-+-+-+-+  1        1                      0.090909
#            2        Is lust in action; and till action, lust           2            1          is LUST in AC tion and.till AC tion               -+-+---+-   -+-+---+-    1        1                      0.000000
#            3        Is perjured, murd'rous, bloody, full of blame,     5            1          is PER jured MURD 'rous BLOO dy FULL of BLAME     -+-+-+-+-+  -+-+-+-+-+   1        3                      0.000000
#            4        Savage, extreme, rude, cruel, not to trust,        9            1          SA vage ex TREME CR uel NOT to TRUST              +--++-+-+   +--++-+-+    1        7                      0.000000
#            5        Enjoyed no sooner but despisèd straight,           14           1          en JOYED no SOO ner BUT des PISÈD straight        -+-+-+-+-   -+++---++    1        12                     0.333333
# ...                                                                                                                                                                                                            ...
#            10       Had, having, and in quest to have, extreme;        21           1          had HA ving and.in QUEST to HAVE ex TREME         -+---+-+-+  -+---+-+-+   1        17                     0.000000
#            11       A bliss in proof and proved, a very woe;           25           1          a BLISS in PROOF and PROVED a VE ry WOE           -+-+-+-+-+  -+-+-+-+-+   1        21                     0.000000
#            12       Before, a joy proposed; behind, a dream.           27           1          be FORE a JOY pro POSED be HIND a DREAM           -+-+-+-+-+  -+-+-+-+-+   1        23                     0.000000
#            13       All this the world well knows; yet none knows well 31           1          ALL this.the WORLD well KNOWS yet NONE knows WELL +--+-+-+-+  +--+++-+++   2        27                     0.200000
#            14       To shun the heaven that leads men to this hell.    33           1          to SHUN the HEA ven THAT leads MEN to.this HELL   -+-+-+-+--+ -+-+-+++--+  2        28                     0.090909
#
#                                                                                                                                                                                                  *total_norm
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                         parse_meter parse_stress sent_num sentpart_num
# 1          1        Th' expense of spirit in a waste of shame          1            1          th'.ex PENSE of SPI rit IN a WASTE of SHAME       --+-+-+-+-+ --+-+-+-+-+  1        1                0.090909
#            2        Is lust in action; and till action, lust           2            1          is LUST in AC tion and.till AC tion               -+-+---+-   -+-+---+-    1        1                0.000000
#            3        Is perjured, murd'rous, bloody, full of blame,     5            1          is PER jured MURD 'rous BLOO dy FULL of BLAME     -+-+-+-+-+  -+-+-+-+-+   1        3                0.000000
#            4        Savage, extreme, rude, cruel, not to trust,        9            1          SA vage ex TREME CR uel NOT to TRUST              +--++-+-+   +--++-+-+    1        7                0.000000
#            5        Enjoyed no sooner but despisèd straight,           14           1          en JOYED no SOO ner BUT des PISÈD straight        -+-+-+-+-   -+++---++    1        12               0.333333
# ...                                                                                                                                                                                                      ...
#            10       Had, having, and in quest to have, extreme;        21           1          had HA ving and.in QUEST to HAVE ex TREME         -+---+-+-+  -+---+-+-+   1        17               0.000000
#            11       A bliss in proof and proved, a very woe;           25           1          a BLISS in PROOF and PROVED a VE ry WOE           -+-+-+-+-+  -+-+-+-+-+   1        21               0.000000
#            12       Before, a joy proposed; behind, a dream.           27           1          be FORE a JOY pro POSED be HIND a DREAM           -+-+-+-+-+  -+-+-+-+-+   1        23               0.000000
#            13       All this the world well knows; yet none knows well 31           1          ALL this.the WORLD well KNOWS yet NONE knows WELL +--+-+-+-+  +--+++-+++   2        27               0.200000
#            14       To shun the heaven that leads men to this hell.    33           1          to SHUN the HEA ven THAT leads MEN to.this HELL   -+-+-+-+--+ -+-+-+++--+  2        28               0.090909
#
# [14 rows x 22 columns]

# %% [markdown]
# This is a lot of information. Let's clean it up a bit. We can extract just the parse score and add our enjambment information.

# %%
import pandas as pd
# Extract the parse score column
df_parse_scores = df[['parse_score']]

# Prepare data for the new DataFrame
data = []

for i in range(len(lines) - 1):
    line = lines[i].strip()

    # Parse lines with SpaCy
    doc = nlp(line)

    # Check for punctuation at the end of the line
    enjambed = "no" if line[-1] in ".;!?," else "yes"

    # Check for substantial enjambment (based on syntactic dependencies)
    last_token = doc[-1]
    hard_enjambment = "yes" if last_token.dep_ in ["cc", "prep", "conj", "det"] else "no"

    # Add the results to the data list
    data.append({
        "The line": line,
        "Parse score": df_parse_scores.iloc[i]["parse_score"],
        "Enjambed?": enjambed,
        "Hard enjambment?": hard_enjambment
    })

# Create a new DataFrame
df_results = pd.DataFrame(data)

# Display the DataFrame
print(df_results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7929a1db8843> in <cell line: 3>()
#       1 import pandas as pd
#       2 # Extract the parse score column
# ----> 3 df_parse_scores = df[['parse_score']]
#       4
#       5 # Prepare data for the new DataFrame
#
# NameError: name 'df' is not defined

# %% [markdown]
# Want to make your table more dynamic? Try Plotly, shown below!

# %%
import plotly.graph_objects as go

# Extract the parse score column
df_parse_scores = df[['parse_score']]

# Prepare data for the new DataFrame
data = []

for i in range(len(lines) - 1):
    line = lines[i].strip()

    # Parse lines with SpaCy
    doc = nlp(line)

    # Check for punctuation at the end of the line
    enjambed = "no" if line[-1] in ".;!?," else "yes"

    # Check for substantial enjambment (based on syntactic dependencies)
    last_token = doc[-1]
    hard_enjambment = "yes" if last_token.dep_ in ["cc", "prep", "conj", "det"] else "no"

    # Add the results to the data list
    data.append({
        "The line": line,
        "Parse score": df_parse_scores.iloc[i]["parse_score"],
        "Enjambed?": enjambed,
        "Hard enjambment?": hard_enjambment
    })

# Create a new DataFrame
df_results = pd.DataFrame(data)

# Create an interactive table using Plotly
fig = go.Figure(data=[
    go.Table(
        header=dict(
            values=["<b>The Line</b>", "<b>Parse Score</b>", "<b>Enjambed?</b>", "<b>Hard Enjambment?</b>"],
            fill_color="lightblue",
            align="left"
        ),
        cells=dict(
            values=[
                df_results["The line"],
                df_results["Parse score"],
                df_results["Enjambed?"],
                df_results["Hard enjambment?"]
            ],
            fill_color="white",
            align="left"
        )
    )
])

# Show the interactive table
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3371db96acde> in <cell line: 4>()
#       2
#       3 # Extract the parse score column
# ----> 4 df_parse_scores = df[['parse_score']]
#       5
#       6 # Prepare data for the new DataFrame
#
# NameError: name 'df' is not defined

# %% [markdown]
# These are just a few kinds of tables and calculations you can show. When you organize your data into a data frame, there's a lot more functions you can run.

# %% [markdown]
# Your turn! Think about the texts and data objects you need in your final project. In the example above, the top level object was the sonnet, and each line was a row. Columns tracked enjambment and metrical complexity. What are your rows anbd columns? You will need to display them. Do your best to create a dataframe (or another data structure if more useful!) and display it. If you struggle to get code running, flag that for future work.

# %%
## your code here

# %% [markdown]
# Final Reflection: What is the primary challenge you are facing when it comes to assembling and/or displaying data? Do you know what your data looks like but need help formatting or analyzing it? Or are you unsure what the data should look like? sometimes there is no "right" or even "best" structure, but it is important to notice when that is the case.
#
# Add your reflection in the text box below.

# %% [markdown]
# YOUR REFLECTION
